# %% [markdown]
# # Hoorcollege 1

# %% [markdown]
# ## Notebook-besturing

# %% [markdown]
# Notebooks stellen je in staat om Pythonscripts te maken die opgebouwd zijn uit meerdere blokken, deze kunnen onafhankelijk van elkaar uitgevoerd worden. Een aantal voordelen hiervan...
# - Je kunt makkelijk de waarden van variabelen inzien, zonder lang bezig te zijn met printcommands, breakpoints, enzovoort.
# - Je kunt de uitvoer van bepaalde scriptstukken inzien zonder het hele script uit te hoeven voeren.
# - Je kunt Notebooks downloaden als .py-bestand. Jupyter maakt dan van vele kleine blokken 1 grote. Vervolgens kan je dit bestand in zijn totaliteit uitvoeren met Spyder (staat automatisch op je apparaat als je Anaconda hebt geïnstalleerd).

# %% [markdown]
# Je zult waarschijnlijk het vaakst gebruikmaken van de volgende bovenstaande iconen...
# - De floppy: je notebook opslaan (shortcut: ctrl + s).
# - Het plusje: een nieuw blok laten verschijnen.
# - Het schaartje: een blok verwijderen. Let op: dit kan niet ongedaan gemaakt worden!
# - De pijltjes naar boven en beneden: een blok naar boven/beneden verplaatsen.
# - De dubbele pijlen naar rechts: alle bouwblokken achter elkaar uitvoeren (van boven naar beneden).
# - De dropdown: hier kies je het vaakst uit:
#     - Code: om Pythoncode te schrijven en uit te voeren met ctrl + enter.
#     - Markdown: voor comments. Door een bepaald aantal #'s te schrijven, gevolgd door een spatie, kan je titels, kopjes, subkopjes, enzovoort geven. Druk ook hier op ctrl + enter om ze er mooi uit te laten zien

# %% [markdown]
# Aandachtspunt: als je een codeblok hebt waarin je een variabele aanmaakt blijft deze in het Notebookgeheugen bestaan, totdat je op de dubbele pijltjes naar rechts klikt.

# %% [markdown]
# ## De basis...

# %%
mijn_naam = "Jelle"
mijn_leeftijd = 27

print("Mijn naam is " + mijn_naam + " en ik ben " + str(mijn_leeftijd) + " jaar")

# %%
mijn_naam

# %% [markdown]
# ## Libraries importeren

# %%
import pandas as pd
import pyodbc

# %% [markdown]
# 2 libraries:
# - Pandas wordt gebruikt om data van externe bestanden in te lezen. In dit geval 3 .accdb-bestanden en 2 CSV-bestanden, maar Excel, .txt, output van API-calls, enzovoort kunnen hier ook in afgevangen worden.
# - Pyodbc is een specifieke library voor het vinden van op de computer opgeslagen databases (in dit geval in Access).

# %% [markdown]
# ## DB-connecties maken

# %%
sales_conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:/Users/jelle/OneDrive - De Haagse Hogeschool/GO gemoderniseerd/go_sales_schoon.accdb;')
staff_conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:/Users/jelle/OneDrive - De Haagse Hogeschool/GO gemoderniseerd/go_staff_schoon.accdb;')
crm_conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:/Users/jelle/OneDrive - De Haagse Hogeschool/GO gemoderniseerd/go_crm_schoon.accdb;')

# %% [markdown]
# Per database wordt hier een conn-variabele aangemaakt. Met behulp van een bestandspad, started met "C:/" en eindigend met ".accdb" wordt naar de 3 databases genavigeerd. Dit bestandspad moet je dus aanpassen, de rest van de string moet je laten staan.

# %% [markdown]
# ## Dataframe aanmaken vanuit SELECT op databasetabel

# %%
product = pd.read_sql("SELECT * FROM product", sales_conn)
product
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST MARGIN  \
# 0               53         10-1-2021                 8           28.55    .28
# 1               54         10-1-2021                 8           35.33    .33
# 2               55         10-1-2021                 8               4     .5
# 3               56         10-1-2021                 8               9     .5
# 4               57         10-1-2021                 9              40     .5
# ..             ...               ...               ...             ...    ...
# 110            108        27-12-2019                19          472.22    .43
# 111            109        10-12-2019                20              35    .43
# 112            110        10-12-2019                20              60     .5
# 113            111        15-12-2019                20            81.8    .55
# 114            112         10-1-2020                21               6    .33
#
# ...

# %% [markdown]
# Je weet als het goed is als dat je met het SQL-statement "SELECT * FROM < tabel >" alle data ontvangt van een bepaalde databasetabel. De bovenstaande code voert dit statement uit op de tabel "product" met behulp van Python Pandas. Hieruit ontstaat een zogeheten dataframe met de zeer treffende variabelenaam 'product'. Met deze tabel/dit frame wordt verder gewerkt in de onderstaande codevoorbeelden.

# %% [markdown]
# <b>Twee belangrijke aandachtspunten voor onderstaande codevoorbeelden:</b>
# - De enige SQL-queries die je bij de practicumopdrachten mag sturen zijn "SELECT * FROM < tabel >, er mag niks achter staan. Python staat namelijk centraal, SQL niet. Je mag SQL wel gebruiken om jezelf te controleren.
# - Het zal misschien opvallen dat print() veelal achterwege gelaten wordt om output van codeblokken te laten zien, slechts de variabelenaam wordt opgeschreven. In Jupyter Notebook werkt dit, maar als je in het uiteindelijke .py-bestand óók de uitvoer op het scherm wil tonen (met behulp van de IDE Spyder) moet je er goed aan denken tijdig de juiste print()-statements in te voeren.

# %% [markdown]
# ## Kolommen selecteren

# %%
product.loc[:, ['PRODUCT_NAME']]
# Out:
#                        PRODUCT_NAME
# 0             Firefly Climbing Lamp
# 1                   Firefly Charger
# 2      Firefly Rechargeable Battery
# 3                 Granite Chalk Bag
# 4                       Granite Ice
# ..                              ...
# 110  Lady Hailstorm Steel Woods Set
# 111               Course Pro Putter
# 112               Blue Steel Putter
# 113           Blue Steel Max Putter
# 114     Course Pro Golf and Tee Set
#
# [115 rows x 1 columns]

# %%
product.loc[:, ['PRODUCT_NAME', 'DESCRIPTION']]

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT PRODUCT_NAME, DESCRIPTION FROM product"
# Het .loc[]-attribuut heeft 2 parameters.
# - De eerste specificeert de rijen die je wilt zien. Voor nu staat hier een dubbele punt, ten teken dat we alle rijen willen zien uit de tabel "product". In de codevoorbeelden verderop kijken we naar alternatieve invullingen.
# - De tweede specificeert de kolommen die je wilt zien. Ook hier kan : staan, ten teken dat we alle kolommen willen zien, maar we specificeren dat we alleen geïnteresseerd zijn in "PRODUCT_NAME" & "DESCRIPTION". Dit doen we door deze kolomnamen tussen een extra set blokhaken te zetten.

# %% [markdown]
# ## Datatypen van kolommen controleren (en eventueel wijzigen)

# %%
product.dtypes
# Out:
# PRODUCT_NUMBER       object
# INTRODUCTION_DATE    object
# PRODUCT_TYPE_CODE    object
# PRODUCTION_COST      object
# MARGIN               object
# PRODUCT_IMAGE        object
# LANGUAGE             object
# PRODUCT_NAME         object
# DESCRIPTION          object
# dtype: object

# %% [markdown]
# Om te weten in hoeverre wiskundige operatoren (+, -, *, enzovoort) en vergelijkingsoperatoren (>, >=, <, <=, enzovoort) mogelijk zijn is het handig om per kolom het datatype op te vragen. Dat wordt gedaan met bovenstaande code. 'Object' is vergelijkbaar met CHAR/VARCHAR in SQL.

# %%
product['PRODUCTION_COST'] = product['PRODUCTION_COST'].astype(float)
product['MARGIN'] = product['MARGIN'].astype(float)

# %% [markdown]
# Met de kolommen "PRODUCTION_COST" & "MARGIN" willen we wiskundige berekeningen uitvoeren, daarom converteren we deze van 'object' naar 'float' (decimaal getal).

# %%
product.dtypes
# Out:
# PRODUCT_NUMBER        object
# INTRODUCTION_DATE     object
# PRODUCT_TYPE_CODE     object
# PRODUCTION_COST      float64
# MARGIN               float64
# PRODUCT_IMAGE         object
# LANGUAGE              object
# PRODUCT_NAME          object
# DESCRIPTION           object
# dtype: object

# %% [markdown]
# Even controleren of de conversie is gelukt. Conclusie: ja :-) .

# %% [markdown]
# ## DISTINCT

# %%
product.loc[:, ['LANGUAGE']].drop_duplicates('LANGUAGE')
# Out:
#   LANGUAGE
# 0       EN

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT DISTINCT LANGUAGE FROM product".
# Kennelijk wordt er slechts 1 taal gebruikt om alle producten te omschrijven

# %%
product.loc[:, ['PRODUCT_NAME', 'LANGUAGE']].drop_duplicates(['PRODUCT_NAME', 'LANGUAGE'])
# Out:
#                        PRODUCT_NAME LANGUAGE
# 0             Firefly Climbing Lamp       EN
# 1                   Firefly Charger       EN
# 2      Firefly Rechargeable Battery       EN
# 3                 Granite Chalk Bag       EN
# 4                       Granite Ice       EN
# ..                              ...      ...
# 110  Lady Hailstorm Steel Woods Set       EN
# 111               Course Pro Putter       EN
# 112               Blue Steel Putter       EN
# 113           Blue Steel Max Putter       EN
# 114     Course Pro Golf and Tee Set       EN
#
# [115 rows x 2 columns]

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT DISTINCT PRODUCT_NAME, LANGUAGE FROM product". Om deze goed uit te voeren moeten beide kolommen tussen blokhaken staan...
# - In de tweede parameter van loc[]
# - Als eerste parameter van drop_duplicates()

# %% [markdown]
# ## Kolommen verwijderen

# %%
product.drop('LANGUAGE', axis = 1)
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 0               53         10-1-2021                 8            28.55
# 1               54         10-1-2021                 8            35.33
# 2               55         10-1-2021                 8             4.00
# 3               56         10-1-2021                 8             9.00
# 4               57         10-1-2021                 9            40.00
# ..             ...               ...               ...              ...
# 110            108        27-12-2019                19           472.22
# 111            109        10-12-2019                20            35.00
# 112            110        10-12-2019                20            60.00
# 113            111        15-12-2019                20            81.80
# 114            112         10-1-2020                21             6.00
#
#      MARGIN    PRODUCT_IMAGE                    PRODUCT_NAME  \
# ...

# %% [markdown]
# We ontdekten hiervóór al dat de kolom 'LANGUAGE' eigenlijk overbodig is, aangezien hier continu 'EN' in staat. Voor analyse is dit dus niet heel relevant. We besluiten daarom om deze kolom te verwijderen met bovenstaande code. 'axis = 1' specificeert dat hij de gegeven te verwijderen string moet zoeken in de kolomnamen, en niet in de rijen van het betreffende dataframe.

# %%
product
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 0               53         10-1-2021                 8            28.55
# 1               54         10-1-2021                 8            35.33
# 2               55         10-1-2021                 8             4.00
# 3               56         10-1-2021                 8             9.00
# 4               57         10-1-2021                 9            40.00
# ..             ...               ...               ...              ...
# 110            108        27-12-2019                19           472.22
# 111            109        10-12-2019                20            35.00
# 112            110        10-12-2019                20            60.00
# 113            111        15-12-2019                20            81.80
# 114            112         10-1-2020                21             6.00
#
#      MARGIN    PRODUCT_IMAGE LANGUAGE                    PRODUCT_NAME  \
# ...

# %% [markdown]
# Huh? Dit is gek! We hadden 'LANGUAGE' toch verwijderd? Hij staat er nu gewoon weer! Hoe kan dat?
# Antwoord: in het codeblok waarin we '.drop(...)' voor het eerst toepasten hebben we slechts een tijdelijke view gecreëerd op het dataframe. Dat wil zeggen dat als je dit frame opnieuw aanroept je de oorspronkelijke versie ervan krijgt (dus inclusief 'LANGUAGE', voordat we deze kolom weghaalden). Dat willen we niet. Oplossing: de gecreëerde view toewijzen aan het oorspronkelijke DataFrame.

# %%
product = product.drop('LANGUAGE', axis = 1)
product
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 0               53         10-1-2021                 8            28.55
# 1               54         10-1-2021                 8            35.33
# 2               55         10-1-2021                 8             4.00
# 3               56         10-1-2021                 8             9.00
# 4               57         10-1-2021                 9            40.00
# ..             ...               ...               ...              ...
# 110            108        27-12-2019                19           472.22
# 111            109        10-12-2019                20            35.00
# 112            110        10-12-2019                20            60.00
# 113            111        15-12-2019                20            81.80
# 114            112         10-1-2020                21             6.00
#
#      MARGIN    PRODUCT_IMAGE                    PRODUCT_NAME  \
# ...

# %% [markdown]
# Nice! Met de "DataFrame = DataFrame"-notatie gaat het wel goed. Vanaf nu krijgen we het geüpdate DataFrame als we "product" aanriepen.

# %% [markdown]
# ## ORDER BY

# %%
product.sort_values('PRODUCTION_COST', ascending = False)
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 107            105        27-12-2019                19           555.90
# 108            106         5-12-2019                19           536.09
# 109            107         13-1-2020                19           509.07
# 52              15          5-3-2013                 2           490.00
# 51              14          5-3-2013                 2           476.00
# ..             ...               ...               ...              ...
# 101             99         15-2-2011                17             2.00
# 93              91         15-2-2011                16             2.00
# 94              92         15-2-2011                16             2.00
# 90              88         15-2-2011                15             2.00
# 53              16          5-3-2013                 2             1.00
#
#      MARGIN    PRODUCT_IMAGE                       PRODUCT_NAME  \
# ...

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT * FROM product ORDER BY production_cost DESC". Let erop dat als je aflopend wilt sorteren, je 'ascending = False' schrijft in de tweede parameter van sort_values(). Als je oplopend wilt sorteren hoef je geen tweede parameter in te vullen.

# %%
product.sort_values(['PRODUCTION_COST', 'MARGIN'], ascending = [False, True])
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 107            105        27-12-2019                19           555.90
# 108            106         5-12-2019                19           536.09
# 109            107         13-1-2020                19           509.07
# 52              15          5-3-2013                 2           490.00
# 51              14          5-3-2013                 2           476.00
# ..             ...               ...               ...              ...
# 101             99         15-2-2011                17             2.00
# 33              86         15-2-2011                15             2.00
# 34              87         15-2-2011                15             2.00
# 90              88         15-2-2011                15             2.00
# 53              16          5-3-2013                 2             1.00
#
#      MARGIN    PRODUCT_IMAGE                       PRODUCT_NAME  \
# ...

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT * FROM product ORDER BY production_cost DESC, margin". Als je de ene kolom aflopend wilt laten sorteren en de andere oplopend: let dan goed op de booleans tussen blokhaken in de tweede parameter van sort_values(). Deze moeten matchen met de kolomnamen tussen blokhaken in de eerste parameter van sort_values (reminder: True is oplopend, False is aflopend).

# %% [markdown]
# ## WHERE

# %% [markdown]
# ### Exacte voorwaarden zonder NULL

# %%
production_cost_more_than_350 = product['PRODUCTION_COST'] > 350
product.loc[production_cost_more_than_350, :]
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 49              12          5-3-2013                 2           473.07
# 50              13         15-2-2011                 2           392.57
# 51              14          5-3-2013                 2           476.00
# 52              15          5-3-2013                 2           490.00
# 82              45         10-1-2021                 6           383.32
# 104            102        10-12-2019                18           380.95
# 107            105        27-12-2019                19           555.90
# 108            106         5-12-2019                19           536.09
# 109            107         13-1-2020                19           509.07
# 110            108        27-12-2019                19           472.22
#
#      MARGIN    PRODUCT_IMAGE                       PRODUCT_NAME  \
# 49     0.23    P12CE1TN2.jpg                          Star Dome
# ...

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT * FROM product WHERE production_cost > 350". Eindelijk kunnen we de eerste parameter van .loc[] invullen. Dit doen we met een boolean...
# - We herhalen de naam van het gecreëerde dataframe ('product').
# - Tussen blokhaken specificeren we de naam van de kolom waarop we willen filteren.
# - We geven met een vergelijkingsoperator (>) en een getal (350) aan welke getallen we wel en niet willen zien.
#
# In de tweede parameter van .loc[] staat :. Reminder: hiermee specificeren we dat we alle kolommen willen zien. We filteren in dit geval dus alleen op rijen (eerste parameter) en niet op kolommen (tweede parameter).

# %%
product.loc[product['PRODUCT_NUMBER'].isna(), :]
#Geeft alle kolommen (':') van alle producten waarvan het PRODUCT_NUMBER onbekend is (kennelijk is dat nooit het geval)
# Out:
# Empty DataFrame
# Columns: [PRODUCT_NUMBER, INTRODUCTION_DATE, PRODUCT_TYPE_CODE, PRODUCTION_COST, MARGIN, PRODUCT_IMAGE, PRODUCT_NAME, DESCRIPTION]
# Index: []

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT * FROM product WHERE PRODUCT_NUMBER IS NULL". Om op NULL-waarden te checken creëren we een boolean door na de blokhaken een functie aan te roepen (.isna()). Kennelijk is het PRODUCT_NUMBER altijd bekend. De tegenhanger van .isna() is trouwens .notna() (vergelijkbaar met "NOT NULL" in SQL).

# %% [markdown]
# ### Niet-exacte voorwaarden met LIKE

# %%
product.dtypes
# Out:
# PRODUCT_NUMBER        object
# INTRODUCTION_DATE     object
# PRODUCT_TYPE_CODE     object
# PRODUCTION_COST      float64
# MARGIN               float64
# PRODUCT_IMAGE         object
# PRODUCT_NAME          object
# DESCRIPTION           object
# dtype: object

# %%
product.loc[product['PRODUCT_NUMBER'].str[0] == '1', :]
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 35             113         15-1-2020                21             6.00
# 36             114        15-12-2019                21            80.00
# 37             115        27-12-2019                21             5.00
# 38               1         15-2-2011                 1             4.00
# 47              10         15-2-2011                 1            10.00
# 48              11         15-2-2011                 2           250.00
# 49              12          5-3-2013                 2           473.07
# 50              13         15-2-2011                 2           392.57
# 51              14          5-3-2013                 2           476.00
# 52              15          5-3-2013                 2           490.00
# 53              16          5-3-2013                 2             1.00
# 54              17          5-3-2013                 3            60.00
# ...

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT * FROM product WHERE PRODUCT_NAME LIKE 'B%'". Ditmaal creëren we de boolean in de eerste parameter van .loc[] met een speciaal attribuut (.str[]). In de blokhaken van str specificeren we met 0 dat alleen de eerste letter van elke waarde van PRODUCT_NAME gecontroleerd moet worden. Index = 0 is namelijk gelijk aan de eerste letter, met index = 1 pak je de tweede letter, enzovoort.

# %%
product.loc[product['PRODUCT_NAME'].str[0:4] == 'Fire', :]
# Out:
#    PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 0              53         10-1-2021                 8            28.55
# 1              54         10-1-2021                 8            35.33
# 2              55         10-1-2021                 8             4.00
# 67             30          5-3-2013                 5             6.75
# 68             31          5-3-2013                 5             7.50
# 69             32         15-2-2011                 5            16.67
# 70             33          5-3-2013                 5            18.00
# 71             34        26-10-2016                 5            28.12
# 72             35        26-10-2016                 5            17.78
#
#     MARGIN  PRODUCT_IMAGE                  PRODUCT_NAME  \
# 0     0.28  P53ME2CA8.jpg         Firefly Climbing Lamp
# 1     0.33  P54ME2CA8.jpg               Firefly Charger
# 2     0.50  P55ME2CA8.jpg  Firefly Rechargeable Battery
# ...

# %%
product.loc[product['PRODUCT_NAME'].str[-1] == 'n', :]
# Out:
#    PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 13             66          5-3-2013                10            45.00
# 15             68         15-2-2011                11            46.15
# 39              2         15-2-2011                 1             9.22
# 78             41         10-1-2021                 5            24.62
# 91             89         15-2-2011                15             2.50
#
#     MARGIN   PRODUCT_IMAGE              PRODUCT_NAME  \
# 13    0.50  P66PA3WT10.jpg  Mountain Man Combination
# 15    0.23  P68PA3EW11.jpg                 Polar Sun
# 39    0.23   P02CE1CG1.jpg         TrailChef Canteen
# 78    0.23   P41CE1LT5.jpg           Flicker Lantern
# 91    0.63  P86OP4IR15.jpg          BugShield Lotion
#
#                                           DESCRIPTION
# 13  Combination watch, altimeter, compass and baro...
# 15  The Polar Sun sunglasses have 3 mm thick lense...
# ...

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT * FROM product WHERE PRODUCT_NAME LIKE '%n'". We voeren nu in .str de index '-1' in. Dit is op het eerste gezicht misschien gek, maar Python staat 'reverse indexing' toe, ten teken dat je als index in reeksen (en waarden zíjn reeksen) ook mingetallen mag uitvoeren. Met index = -1 pak je de laatste letter, met index = -2 pak je de een-na-laatste letter, enzovoort.

# %%
product.loc[product['PRODUCT_NAME'].str.contains('e'), :]
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 0               53         10-1-2021                 8            28.55
# 1               54         10-1-2021                 8            35.33
# 2               55         10-1-2021                 8             4.00
# 3               56         10-1-2021                 8             9.00
# 4               57         10-1-2021                 9            40.00
# ..             ...               ...               ...              ...
# 110            108        27-12-2019                19           472.22
# 111            109        10-12-2019                20            35.00
# 112            110        10-12-2019                20            60.00
# 113            111        15-12-2019                20            81.80
# 114            112         10-1-2020                21             6.00
#
#      MARGIN    PRODUCT_IMAGE                    PRODUCT_NAME  \
# ...

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT * FROM product WHERE PRODUCT_NAME LIKE '%e%'". In plaats van de blokhaken na str in te vullen roepen we nu een functie aan (.contains). Hierin specificeren we een mogelijke invulling die overal in de betreffende rijwaarden voor mag komen (begin, eind, midden; het maakt niet uit).

# %% [markdown]
# ### Voorwaarden met logische operatoren (AND & OR)

# %%
product_name_begins_with_b = product['PRODUCT_NAME'].str[0] == 'B'
product_name_ends_with_s = product['PRODUCT_NAME'].str[-1] == 's'

product.loc[(product_name_begins_with_b) & (product_name_ends_with_s), :]
# Out:
# Empty DataFrame
# Columns: [PRODUCT_NUMBER, INTRODUCTION_DATE, PRODUCT_TYPE_CODE, PRODUCTION_COST, MARGIN, PRODUCT_IMAGE, PRODUCT_NAME, DESCRIPTION]
# Index: []

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT * FROM product WHERE PRODUCT_NAME LIKE 'B%' OR PRODUCT_NAME LIKE '%s%'". In de eerste parameter van .loc[] creëren we 2 booleans, elk van hen wordt gescheiden door ronde haakjes en een logische operator. 2 keuzes:
# - & voor 'AND' (alle booleans moeten waar zijn, wil de rij in de selectie opgenomen worden).
# - | voor 'OR' (slechts 1 boolean hoeft waar te zijn, wil de rij in de selectie opgenomen worden).

# %% [markdown]
# ## COUNT(), SUM(), AVG(), MIN(), MAX() & ROUND()

# %%
product.shape[0]

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT COUNT(*) FROM product". In 'shape' wordt op index 0 het aantal rijen opgeslagen en op index 1 het aantal kolommen.

# %%
product['PRODUCTION_COST'].sum()

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT SUM(PRODUCTION_COST) FROM product".

# %%
round(product['PRODUCTION_COST'].mean(), 2)

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT ROUND(AVG(PRODUCTION_COST), 2) FROM product".

# %%
product['PRODUCTION_COST'].min()

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT MIN(PRODUCTION_COST) FROM product".

# %%
product['PRODUCTION_COST'].max()

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT MAX(PRODUCTION_COST) FROM product".

# %% [markdown]
# ## GROUP BY

# %%
grouped = product.groupby('PRODUCT_TYPE_CODE')['PRODUCTION_COST'].mean().reset_index()
grouped = grouped.rename(columns = {'PRODUCTION_COST' : 'AVG_PRODUCTION_COST'})

grouped

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT PRODUCT_TYPE_CODE, AVG(PRODUCTION_COST) FROM product GROUP BY PRODUCT_TYPE_CODE". De rename is nodig, omdat anders de kolomnaam "PRODUCTION_COST" letterlijk blijft staan. Voor de raadpleger van dit dataframe is het wel zo aardig om duidelijk te maken dat het om een gemiddelde gaat, dus maken we hier "AVG_PRODUCTION_COST" van. Merk op dat je hier eerst een dataframe 'grouped' aanmaakt en deze vervolgens overschrijft door de rename hieraan toe te voegen: met 'grouped = grouped' wijzig je dus het oorspronkelijke dataframe.

# %%
grouped.loc[grouped['AVG_PRODUCTION_COST'] < 100, :]

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT PRODUCT_TYPE_CODE, AVG(PRODUCTION_COST) FROM product GROUP BY PRODUCT_TYPE_CODE HAVING AVG(PRODUCTION_COST) < 100". We hadden de GROUP BY al toegepast, het dataframe 'grouped' is daar het resultaat van. De HAVING realiseren we door .loc[] op grouped toe te passen en de eerste parameter daarvan in te vullen met een boolean.

# %% [markdown]
# ## JOIN

# %%
order_details = pd.read_sql("SELECT * FROM order_details", sales_conn)
order_details

# %% [markdown]
# Om de JOIN te demonstreren (zie hieronder) wordt van een tweede databasetabel (order_details) een dataframe gemaakt.

# %%
joined = pd.merge(product, order_details, on = 'PRODUCT_NUMBER', how = 'inner')
joined

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT od.order_detail_code, p.product_type_code FROM product p JOIN order_details od ON p.product_number = od.product_number". Als je meerdere joins wilt uitvoeren zul je je reeds gemaakt 'joined'-dataframe moeten overschrijven. Met how = 'inner' geef je ten slotte aan dat het om een INNER JOIN gaat, je kan hier ook 'left' (voor een LEFT JOIN), 'right' (voor een RIGHT JOIN) en 'outer' (voor een OUTER JOIN) schrijven.

# %% [markdown]
# ## SUBSELECT (IN)

# %%
product.loc[product['PRODUCTION_COST'] == product['PRODUCTION_COST'].min(), :]

# %% [markdown]
# Dit is het Pythonequivalent van de SQL-query: "SELECT * FROM product WHERE production_cost = (SELECT MIN(production_cost) FROM product). Je ziet dat je subselects makkelijk kan uitvoeren door de eerderbesproken Pythonfuncties in te voegen in de boolean op de eerste parameter van .loc[].

# %% [markdown]
# ## UNION TODO

# %%
product1 = product.iloc[:80]
product2 = product.iloc[80:]
product1

# %% [markdown]
# Om te demonstreren hoe je een SQL UNION simuleert in Python wordt in de bovenstaande coderegel het DataFrame "Product" horizontaal opgesplitst. Deze willen we uiteindelijk dus weer verticaal samenvoegen, zodat we weer slechts één producttabel hebben

# %%
product = product1.append(product2)
product

# %% [markdown]
# De UNION is nu uitgevoerd

# %% [markdown]
# ## IIF & CASE

# %%
for index, row in product.iterrows():
    production_cost = product.at[index, 'PRODUCTION_COST']
    
    if(production_cost < 100):
        product.at[index, 'MARGIN_RANKING'] = 'cheap'
    elif(production_cost < 200):
        product.at[index, 'MARGIN_RANKING'] = 'a bit expensive'
    else:
        product.at[index, 'MARGIN_RANKING'] = 'very expensive'

product

# %% [markdown]
# De code-loop hierboven loopt elke rij langs van het DataFrame "Product". Bij elke rij die langsgelopen wordt krijgt de variabele "index" de indexwaarde (zie de dikgedrukte getallen in de eerste kolom). Met behulp van .at[] kan je op deze index en een gespecificeerde kolom een bepaalde waarde ophalen en deze ook (conditioneel) wijzigen. Het mooie hiervan? Als de gespecificeerde kolom niet bestaat (wat in dit geval zo is bij 'MARGIN_RANKING') maakt Python die kolom zelf aan, als laatste kolom in het DataFrame.

# %% [markdown]
# ## Exporteren naar Excel

# %%
product.to_excel("Product NEW.xlsx")
